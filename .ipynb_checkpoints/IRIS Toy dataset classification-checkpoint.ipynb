# %% [markdown]
# ## Load Libraries

# %%
from sklearn import datasets

# %%
import numpy as np
import pandas as pd
import pandas.plotting as pplt

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, f1_score, precision_recall_fscore_support
from sklearn.linear_model import LogisticRegressionCV, RidgeClassifierCV, LogisticRegression

# %% [markdown]
# ### Load Data

# %%
X,y = datasets.load_iris(return_X_y=True, as_frame=True)

# %%
X.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2

# %%
target.head(3)
# Out:
# 0    0
# 1    0
# 2    0
# Name: target, dtype: int32

# %% [markdown]
# ### EDA Analysis

# %%
pplt.andrews_curves(target,'target')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-f89a9a89d8e5> in <module>
# ----> 1 pplt.andrews_curves(target,'target')
#
# ~\Anaconda3\envs\deepcpu\lib\site-packages\pandas\plotting\_misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwargs)
#     276         color=color,
#     277         colormap=colormap,
# --> 278         **kwargs,
#     279     )
#     280
#
# ~\Anaconda3\envs\deepcpu\lib\site-packages\pandas\plotting\_matplotlib\misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwds)
#     250
#     251     n = len(frame)
# --> 252     class_col = frame[class_column]
#     253     classes = frame[class_column].drop_duplicates()
#     254     df = frame.drop(class_column, axis=1)
#
# ~\Anaconda3\envs\deepcpu\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
# ...
